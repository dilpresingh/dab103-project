# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading Data

# %%
my_data = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/AER/STAR.csv')
my_data
# Out:
#        Unnamed: 0  gender ethnicity    birth         stark         star1  \
# 0            1122  female      afam  1979 Q3           NaN           NaN
# 1            1137  female      cauc  1980 Q1         small         small
# 2            1143  female      afam  1979 Q4         small         small
# 3            1160    male      cauc  1979 Q4           NaN           NaN
# 4            1183    male      afam  1980 Q1  regular+aide           NaN
# ...           ...     ...       ...      ...           ...           ...
# 11593      186650    male      cauc  1979 Q3         small         small
# 11594      186665  female      cauc  1980 Q3       regular       regular
# 11595      186687    male      cauc  1980 Q1           NaN       regular
# 11596      186705  female      afam  1980 Q1       regular  regular+aide
# 11597      186718    male      afam  1980 Q2  regular+aide  regular+aide
#
#               star2         star3  readk  read1  ...  tethnicity2  \
# ...

# %% [markdown]
# # EDA

# %%
my_data.head(10)
# Out:
#    Unnamed: 0  gender ethnicity    birth         stark         star1  \
# 0        1122  female      afam  1979 Q3           NaN           NaN
# 1        1137  female      cauc  1980 Q1         small         small
# 2        1143  female      afam  1979 Q4         small         small
# 3        1160    male      cauc  1979 Q4           NaN           NaN
# 4        1183    male      afam  1980 Q1  regular+aide           NaN
# 5        1195    male      cauc  1979 Q3           NaN           NaN
# 6        1215    male      afam  1979 Q1           NaN           NaN
# 7        1224  female      cauc  1979 Q4           NaN  regular+aide
# 8        1246    male      cauc  1979 Q2           NaN       regular
# 9        1258    male      cauc  1979 Q3           NaN       regular
#
#           star2         star3  readk  read1  ...  tethnicity2  tethnicity3  \
# 0           NaN       regular    NaN    NaN  ...          NaN         cauc
# ...

# %%
my_data.tail(10)
# Out:
#        Unnamed: 0  gender ethnicity    birth         stark         star1  \
# 11588      186574  female      cauc  1979 Q2           NaN           NaN
# 11589      186586  female      afam  1979 Q3           NaN       regular
# 11590      186604    male      cauc  1980 Q2         small         small
# 11591      186614  female      cauc  1978 Q4           NaN       regular
# 11592      186634    male      cauc  1980 Q3         small         small
# 11593      186650    male      cauc  1979 Q3         small         small
# 11594      186665  female      cauc  1980 Q3       regular       regular
# 11595      186687    male      cauc  1980 Q1           NaN       regular
# 11596      186705  female      afam  1980 Q1       regular  regular+aide
# 11597      186718    male      afam  1980 Q2  regular+aide  regular+aide
#
#               star2         star3  readk  read1  ...  tethnicity2  \
# 11588  regular+aide  regular+aide    NaN    NaN  ...         cauc
# ...

# %%
type(my_data)
# Out:
# pandas.core.frame.DataFrame

# %%
my_data.shape
# Out:
# (11598, 48)

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11598 entries, 0 to 11597
# Data columns (total 48 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   11598 non-null  int64
#  1   gender       11578 non-null  object
#  2   ethnicity    11453 non-null  object
#  3   birth        11528 non-null  object
#  4   stark        6325 non-null   object
#  5   star1        6829 non-null   object
#  6   star2        6840 non-null   object
#  7   star3        6802 non-null   object
#  8   readk        5789 non-null   float64
#  9   read1        6396 non-null   float64
#  10  read2        6077 non-null   float64
#  11  read3        6000 non-null   float64
#  12  mathk        5871 non-null   float64
#  13  math1        6600 non-null   float64
#  14  math2        6065 non-null   float64
#  15  math3        6077 non-null   float64
#  16  lunchk       6302 non-null   object
#  17  lunch1       6651 non-null   object
# ...

# %% [markdown]
# **Redundant Column**

# %%
my_data['Unnamed: 0']
# Out:
# 0          1122
# 1          1137
# 2          1143
# 3          1160
# 4          1183
#           ...
# 11593    186650
# 11594    186665
# 11595    186687
# 11596    186705
# 11597    186718
# Name: Unnamed: 0, Length: 11598, dtype: int64

# %% [markdown]
# ### Females in the dataset

# %%
females =  my_data[my_data.gender == 'female']
females
# Out:
#        Unnamed: 0  gender ethnicity    birth         stark         star1  \
# 0            1122  female      afam  1979 Q3           NaN           NaN
# 1            1137  female      cauc  1980 Q1         small         small
# 2            1143  female      afam  1979 Q4         small         small
# 7            1224  female      cauc  1979 Q4           NaN  regular+aide
# 13           1324  female      afam  1980 Q2  regular+aide       regular
# ...           ...     ...       ...      ...           ...           ...
# 11588      186574  female      cauc  1979 Q2           NaN           NaN
# 11589      186586  female      afam  1979 Q3           NaN       regular
# 11591      186614  female      cauc  1978 Q4           NaN       regular
# 11594      186665  female      cauc  1980 Q3       regular       regular
# 11596      186705  female      afam  1980 Q1       regular  regular+aide
#
#               star2         star3  readk  read1  ...  tethnicity2  \
# ...

# %%
females.shape
# Out:
# (5456, 48)

# %% [markdown]
# **Proportion of Females**

# %%
females.shape[0]/my_data.shape[0]
# Out:
# 0.4704259355061217

# %% [markdown]
# ###  Caucasians in the dataset

# %%
cauc =  my_data[my_data.ethnicity == 'cauc']
cauc
# Out:
#        Unnamed: 0  gender ethnicity    birth    stark         star1  \
# 1            1137  female      cauc  1980 Q1    small         small
# 3            1160    male      cauc  1979 Q4      NaN           NaN
# 5            1195    male      cauc  1979 Q3      NaN           NaN
# 7            1224  female      cauc  1979 Q4      NaN  regular+aide
# 8            1246    male      cauc  1979 Q2      NaN       regular
# ...           ...     ...       ...      ...      ...           ...
# 11591      186614  female      cauc  1978 Q4      NaN       regular
# 11592      186634    male      cauc  1980 Q3    small         small
# 11593      186650    male      cauc  1979 Q3    small         small
# 11594      186665  female      cauc  1980 Q3  regular       regular
# 11595      186687    male      cauc  1980 Q1      NaN       regular
#
#               star2         star3  readk  read1  ...  tethnicity2  \
# 1             small         small  447.0  507.0  ...         cauc
# ...

# %%
cauc.shape
# Out:
# (7193, 48)

# %% [markdown]
# **Proportion of Caucasians**

# %%
cauc.shape[0]/my_data.shape[0]
# Out:
# 0.6201931367477151

# %% [markdown]
# **Grouping by Ethnicity**

# %%
gk=my_data.groupby('ethnicity')
gk.first()
# Out:
#            Unnamed: 0  gender    birth         stark         star1  \
# ethnicity
# afam             1122  female  1979 Q3         small         small
# amindian        16222    male  1980 Q2         small         small
# asian            7278    male  1980 Q2       regular       regular
# cauc             1137  female  1980 Q1         small         small
# hispanic         2872  female  1979 Q4  regular+aide  regular+aide
# other           13163    male  1980 Q3         small       regular
#
#                   star2    star3  readk  read1  read2  ...  tethnicity2  \
# ethnicity                                              ...
# afam       regular+aide  regular  450.0  579.0  588.0  ...         afam
# amindian        regular     None  414.0  540.0  541.0  ...         cauc
# asian           regular  regular  413.0  604.0  669.0  ...         afam
# cauc              small    small  447.0  507.0  568.0  ...         cauc
# ...

# %% [markdown]
# **Data grouped by African American community**

# %%
gk.get_group('afam')
# Out:
#        Unnamed: 0  gender ethnicity    birth         stark         star1  \
# 0            1122  female      afam  1979 Q3           NaN           NaN
# 2            1143  female      afam  1979 Q4         small         small
# 4            1183    male      afam  1980 Q1  regular+aide           NaN
# 6            1215    male      afam  1979 Q1           NaN           NaN
# 13           1324  female      afam  1980 Q2  regular+aide       regular
# ...           ...     ...       ...      ...           ...           ...
# 11579      186427    male      afam  1979 Q3           NaN       regular
# 11584      186506    male      afam  1980 Q3         small           NaN
# 11589      186586  female      afam  1979 Q3           NaN       regular
# 11596      186705  female      afam  1980 Q1       regular  regular+aide
# 11597      186718    male      afam  1980 Q2  regular+aide  regular+aide
#
#               star2         star3  readk  read1  ...  tethnicity2  \
# ...

# %% [markdown]
# ### Data Description

# %%
my_data.describe()
# Out:
#           Unnamed: 0        readk        read1        read2        read3  \
# count   11598.000000  5789.000000  6396.000000  6077.000000  6000.000000
# mean    93914.585618   436.725341   520.784553   583.934836   615.412500
# std     53588.594738    31.706262    55.188498    46.043040    38.566167
# min      1122.000000   315.000000   404.000000   468.000000   499.000000
# 25%     47500.250000   414.000000   478.000000   552.000000   588.000000
# 50%     93927.500000   433.000000   514.000000   582.000000   614.000000
# 75%    140307.750000   453.000000   558.000000   614.000000   641.000000
# max    186718.000000   627.000000   651.000000   732.000000   775.000000
#
#              mathk        math1        math2        math3  experiencek  ...  \
# count  5871.000000  6600.000000  6065.000000  6077.000000  6304.000000  ...
# mean    485.377108   530.534697   580.612531   617.968076     9.258249  ...
# std      47.697880    43.103920    44.573987    39.838168     5.808783  ...
# ...

# %% [markdown]
# ### Data Type Identification

# %% [markdown]
# **Categorical Data**

# %%
my_data.describe(include=['O'])
# Out:
#        gender ethnicity    birth         stark    star1         star2  \
# count   11578     11453    11528          6325     6829          6840
# unique      2         6       21             3        3             3
# top      male      cauc  1980 Q3  regular+aide  regular  regular+aide
# freq     6122      7193     2304          2231     2584          2495
#
#                star3    lunchk lunch1 lunch2  ...   degree2   degree3 ladderk  \
# count           6802      6302   6651   6496  ...      6779      6736    5729
# unique             3         2      2      2  ...         4         3       6
# top     regular+aide  non-free   free   free  ...  bachelor  bachelor  level1
# freq            2543      3250   3430   3336  ...      4249      3762    4671
#
#        ladder1 ladder2 ladder3 tethnicityk tethnicity1 tethnicity2 tethnicity3
# count     6787    6720    6751        6263        6776        6779        6751
# ...

# %% [markdown]
# **Numerical Data**

# %%
my_data.iloc[:,0:35].describe(exclude=['O'])
# Out:
#           Unnamed: 0        readk        read1        read2        read3  \
# count   11598.000000  5789.000000  6396.000000  6077.000000  6000.000000
# mean    93914.585618   436.725341   520.784553   583.934836   615.412500
# std     53588.594738    31.706262    55.188498    46.043040    38.566167
# min      1122.000000   315.000000   404.000000   468.000000   499.000000
# 25%     47500.250000   414.000000   478.000000   552.000000   588.000000
# 50%     93927.500000   433.000000   514.000000   582.000000   614.000000
# 75%    140307.750000   453.000000   558.000000   614.000000   641.000000
# max    186718.000000   627.000000   651.000000   732.000000   775.000000
#
#              mathk        math1        math2        math3  experiencek  \
# count  5871.000000  6600.000000  6065.000000  6077.000000  6304.000000
# mean    485.377108   530.534697   580.612531   617.968076     9.258249
# std      47.697880    43.103920    44.573987    39.838168     5.808783
# ...

# %% [markdown]
# ### Unique values

# %%
my_data.nunique()
# Out:
# Unnamed: 0     11598
# gender             2
# ethnicity          6
# birth             21
# stark              3
# star1              3
# star2              3
# star3              3
# readk             93
# read1             86
# read2             93
# read3             90
# mathk             38
# math1             67
# math2             87
# math3             94
# lunchk             2
# lunch1             2
# lunch2             2
# lunch3             2
# schoolk            4
# school1            4
# school2            4
# school3            4
# degreek            4
# degree1            4
# degree2            4
# degree3            3
# ladderk            6
# ladder1            6
# ladder2            6
# ladder3            6
# experiencek       25
# experience1       40
# experience2       38
# experience3       38
# tethnicityk        2
# tethnicity1        2
# tethnicity2        2
# tethnicity3        3
# systemk           42
# system1           42
# system2           41
# ...

# %% [markdown]
# ### Missing Values

# %%
my_data.isnull().sum()
# Out:
# Unnamed: 0        0
# gender           20
# ethnicity       145
# birth            70
# stark          5273
# star1          4769
# star2          4758
# star3          4796
# readk          5809
# read1          5202
# read2          5521
# read3          5598
# mathk          5727
# math1          4998
# math2          5533
# math3          5521
# lunchk         5296
# lunch1         4947
# lunch2         5102
# lunch3         5078
# schoolk        5273
# school1        4769
# school2        4758
# school3        4796
# degreek        5294
# degree1        4788
# degree2        4819
# degree3        4862
# ladderk        5869
# ladder1        4811
# ladder2        4878
# ladder3        4847
# experiencek    5294
# experience1    4788
# experience2    4860
# experience3    4847
# tethnicityk    5335
# tethnicity1    4822
# tethnicity2    4819
# tethnicity3    4847
# systemk        5273
# system1        4769
# system2        4758
# system3        4796
# schoolidk      5273
# ...

# %% [markdown]
# ### Duplicate records

# %%
duplicate=my_data.iloc[:,1:43].duplicated()
my_data.iloc[:,1:48][duplicate]
# Out:
#        gender ethnicity    birth         stark    star1    star2  \
# 2376     male      afam  1980 Q1  regular+aide      NaN      NaN
# 4042     male       NaN  1980 Q2           NaN      NaN  regular
# 5632     male      afam  1979 Q3           NaN      NaN  regular
# 6577   female      afam  1979 Q2           NaN      NaN      NaN
# 6594   female      cauc  1979 Q4  regular+aide      NaN      NaN
# 7090     male      cauc  1980 Q2         small      NaN      NaN
# 8869     male      afam  1980 Q1  regular+aide      NaN      NaN
# 9501   female      afam      NaN           NaN      NaN      NaN
# 9752     male      cauc  1979 Q4           NaN      NaN      NaN
# 9943     male       NaN  1980 Q3           NaN      NaN    small
# 9978     male       NaN  1980 Q3           NaN      NaN      NaN
# 10950    male      cauc  1979 Q4           NaN      NaN    small
# 11196    male      afam  1980 Q2           NaN  regular      NaN
# ...

# %% [markdown]
# ### Correlations

# %%
corr=my_data.iloc[:,1:40].corr()
corr
# Out:
#                 readk     read1     read2     read3     mathk     math1  \
# readk        1.000000  0.599100  0.519589  0.473047  0.713404  0.527819
# read1        0.599100  1.000000  0.757775  0.667194  0.506667  0.725963
# read2        0.519589  0.757775  1.000000  0.767803  0.466346  0.614991
# read3        0.473047  0.667194  0.767803  1.000000  0.430378  0.550043
# mathk        0.713404  0.506667  0.466346  0.430378  1.000000  0.595415
# math1        0.527819  0.725963  0.614991  0.550043  0.595415  1.000000
# math2        0.466595  0.618511  0.723960  0.618922  0.527405  0.710270
# math3        0.426325  0.569768  0.645991  0.745460  0.478108  0.646783
# experiencek  0.112668  0.093174  0.072969  0.040637  0.100021  0.069217
# experience1  0.043198  0.048245  0.026747  0.021509  0.070719  0.004931
# experience2 -0.005517 -0.021023  0.041146 -0.016551 -0.004182 -0.034751
# experience3  0.021283 -0.023743 -0.021116 -0.005751 -0.020800 -0.036484
#
# ...

# %%
fig = plt.figure(figsize=(12,12))
dataplot=sns.heatmap(corr,cmap='RdBu',annot=True)
plt.title('Correlation Plot')
# Out:
# Text(0.5, 1.0, 'Correlation Plot')

# %% [markdown]
# # Scatter Plots For Strongly Corrrelated Variables

# %%
fig = plt.figure(figsize=(12,12))

plt.subplot(3, 2, 1)
sns.scatterplot(x="readk",
                    y="mathk",
                    data=my_data)
plt.xlabel("Total reading scaled score in kindergarten")
plt.ylabel("Total math scaled score in kindergarten")

plt.subplot(3, 2, 2)
sns.scatterplot(x="read1",
                    y="read2",
                    data=my_data)
plt.xlabel("Total reading scaled score in 1st grade")
plt.ylabel("Total reading scaled score in 2nd grade")

plt.subplot(3, 2, 3)
sns.scatterplot(x="read1",
                    y="math1",
                    data=my_data)
plt.xlabel("Total reading scaled score in 1st grade")
plt.ylabel("Total math scaled score in 1st grade")

plt.subplot(3, 2, 4)
sns.scatterplot(x="read2",
                    y="read3",
                    data=my_data)
plt.xlabel("Total reading scaled score in 1st grade")
plt.ylabel("Total reading scaled score in 3rd grade")

plt.subplot(3, 2, 5)
sns.scatterplot(x="read2",
                    y="math2",
                    data=my_data)
plt.xlabel("Total reading scaled score in 2nd grade")
plt.ylabel("Total math scaled score in 2nd grade")

plt.subplot(3, 2, 6)
sns.scatterplot(x="read3",
                    y="math3",
                    data=my_data)
plt.xlabel("Total reading scaled score in 3rd grade")
plt.ylabel("Total math scaled score in 3rd grade")

plt.suptitle("Scatter Plots For Strongly Corrrelated Variables")
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Outliers

# %%
my_data.iloc[:,1:35].boxplot(rot=70,fontsize=10)
plt.xlabel("Numerical Data")
plt.ylabel("Values")
plt.title("Outliers Plot")
# Out:
# Text(0.5, 1.0, 'Outliers Plot')

# %% [markdown]
# ### Categorical analysis

# %%
my_data['gender'].value_counts().plot(kind='pie',title='Student Gender Breakdown',autopct='%1.1f%%',labels= ['Male', 'Female'],ylabel='Gender',explode=(0.05, 0.05),shadow=True)
# Out:
# <AxesSubplot:title={'center':'Student Gender Breakdown'}, ylabel='Gender'>

# %%
g=sns.countplot(x=my_data.ethnicity,palette='cubehelix')
g.set_title('Student Ethnicity Distribution')
g.set_ylabel("Count")
g.set_xlabel("Ethnicity")
# Out:
# Text(0.5, 0, 'Ethnicity')

# %%
fig = plt.figure(figsize=(8,8))

plt.subplot(2, 2, 1)
my_data['stark'].value_counts().plot(kind='bar')
plt.title("Kindergarten")
plt.ylabel("Count")

plt.subplot(2, 2, 2)
my_data['star1'].value_counts().plot(kind='bar')
plt.title("First Grade")
plt.ylabel("Count")

plt.subplot(2, 2, 3)
my_data['star2'].value_counts().plot(kind='bar')
plt.title("Second Grade")
plt.ylabel("Count")

plt.subplot(2, 2, 4)
my_data['star3'].value_counts().plot(kind='bar')
plt.title("Third Grade")
plt.ylabel("Count")

plt.suptitle("Distribution of students across different STAR class types for different grades")
fig.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(8,8))

plt.subplot(2, 2, 1)
my_data['degreek'].value_counts().plot(kind='bar')
plt.title("Kindergarten")
plt.ylabel("Count")

plt.subplot(2, 2, 2)
my_data['degree1'].value_counts().plot(kind='bar')
plt.title("First Grade")
plt.ylabel("Count")

plt.subplot(2, 2, 3)
my_data['degree2'].value_counts().plot(kind='bar')
plt.title("Second Grade")
plt.ylabel("Count")

plt.subplot(2, 2, 4)
my_data['degree3'].value_counts().plot(kind='bar')
plt.title("Third Grade")
plt.ylabel("Count")

plt.suptitle("Distribution of teachers by highest degree across different grades")
fig.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(8,8))

plt.subplot(2, 2, 1)
my_data['ladderk'].value_counts().plot(kind='bar')
plt.title("Kindergarten")
plt.ylabel("Count")

plt.subplot(2, 2, 2)
my_data['ladder1'].value_counts().plot(kind='bar')
plt.title("First Grade")
plt.ylabel("Count")

plt.subplot(2, 2, 3)
my_data['ladder2'].value_counts().plot(kind='bar')
plt.title("Second Grade")
plt.ylabel("Count")

plt.subplot(2, 2, 4)
my_data['ladder3'].value_counts().plot(kind='bar')
plt.title("Third Grade")
plt.ylabel("Count")

plt.suptitle("Distribution of teachers by career ladder level across different grades")
fig.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(8,8))

plt.subplot(2, 2, 1)
my_data['tethnicityk'].value_counts().plot(kind='bar')
plt.title("Kindergarten")
plt.ylabel("Count")

plt.subplot(2, 2, 2)
my_data['tethnicity1'].value_counts().plot(kind='bar')
plt.title("First Grade")
plt.ylabel("Count")

plt.subplot(2, 2, 3)
my_data['tethnicity2'].value_counts().plot(kind='bar')
plt.title("Second Grade")
plt.ylabel("Count")

plt.subplot(2, 2, 4)
my_data['tethnicity3'].value_counts().plot(kind='bar')
plt.title("Third Grade")
plt.ylabel("Count")

plt.suptitle("Distribution of teachers by ethnicity across different grades")
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Further Data Exploration

# %% [markdown]
# **Distribution of students by ethnicity and class size in different grades**

# %%
fig = plt.figure(figsize=(10,10))

plt.subplot(2, 2, 1)
sns.heatmap(pd.crosstab(my_data.ethnicity,my_data.stark),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Kindergarten")
plt.xlabel("Class Size")
plt.ylabel("Student Ethnicity")

plt.subplot(2, 2, 2)
sns.heatmap(pd.crosstab(my_data.ethnicity,my_data.star1),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("First Grade")
plt.xlabel("Class Size")
plt.ylabel("Student Ethnicity")

plt.subplot(2, 2, 3)
sns.heatmap(pd.crosstab(my_data.ethnicity,my_data.star2),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Second Grade")
plt.xlabel("Class Size")
plt.ylabel("Student Ethnicity")

plt.subplot(2, 2, 4)
sns.heatmap(pd.crosstab(my_data.ethnicity,my_data.star3),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Third Grade")
plt.xlabel("Class Size")
plt.ylabel("Student Ethnicity")

plt.suptitle("Distribution of students by ethnicity and class size in different grades")
fig.tight_layout()
plt.show()

# %% [markdown]
# **Distribution of students by ethnicity and school type in different grades**

# %%
fig = plt.figure(figsize=(8,8))

plt.subplot(2, 2, 1)
sns.heatmap(pd.crosstab(my_data.ethnicity,my_data.schoolk),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Kindergarten")
plt.xlabel("School Type")
plt.ylabel("Student Ethnicity")

plt.subplot(2, 2, 2)
sns.heatmap(pd.crosstab(my_data.ethnicity,my_data.school1),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("First Grade")
plt.xlabel("School Type")
plt.ylabel("Student Ethnicity")

plt.subplot(2, 2, 3)
sns.heatmap(pd.crosstab(my_data.ethnicity,my_data.school2),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Second Grade")
plt.xlabel("School Type")
plt.ylabel("Student Ethnicity")

plt.subplot(2, 2, 4)
sns.heatmap(pd.crosstab(my_data.ethnicity,my_data.school3),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Third Grade")
plt.xlabel("School Type")
plt.ylabel("Student Ethnicity")

plt.suptitle("Distribution of students by ethnicity and school type in different grades")
fig.tight_layout()
plt.show()

# %% [markdown]
# **Distribution of teachers by ethnicity and class size in different grades**

# %%
fig = plt.figure(figsize=(8,8))

plt.subplot(2, 2, 1)
sns.heatmap(pd.crosstab(my_data.tethnicityk,my_data.stark),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Kindergarten")
plt.xlabel("Class Size")
plt.ylabel("Teacher ethnicity")

plt.subplot(2, 2, 2)
sns.heatmap(pd.crosstab(my_data.tethnicity1,my_data.star1),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("First Grade")
plt.xlabel("Class Size")
plt.ylabel("Teacher ethnicity")

plt.subplot(2, 2, 3)
sns.heatmap(pd.crosstab(my_data.tethnicity2,my_data.star2),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Second Grade")
plt.xlabel("Class Size")
plt.ylabel("Teacher ethnicity")

plt.subplot(2, 2, 4)
sns.heatmap(pd.crosstab(my_data.tethnicity3,my_data.star3),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Third Grade")
plt.xlabel("Class Size")
plt.ylabel("Teacher ethnicity")

plt.suptitle("Distribution of teachers by ethnicity and class size in different grades")
fig.tight_layout()
plt.show()

# %% [markdown]
# **Distribution of teachers by ethnicity and school type in different grades**

# %%
fig = plt.figure(figsize=(8,8))

plt.subplot(2, 2, 1)
sns.heatmap(pd.crosstab(my_data.tethnicityk,my_data.schoolk),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Kindergarten")
plt.xlabel("School Type")
plt.ylabel("Teacher ethnicity")

plt.subplot(2, 2, 2)
sns.heatmap(pd.crosstab(my_data.tethnicity1,my_data.school1),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("First Grade")
plt.xlabel("School Type")
plt.ylabel("Teacher ethnicity")

plt.subplot(2, 2, 3)
sns.heatmap(pd.crosstab(my_data.tethnicity2,my_data.school2),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Second Grade")
plt.xlabel("School Type")
plt.ylabel("Teacher ethnicity")

plt.subplot(2, 2, 4)
sns.heatmap(pd.crosstab(my_data.tethnicity3,my_data.school3),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Third Grade")
plt.xlabel("School Type")
plt.ylabel("Teacher ethnicity")

plt.suptitle("Distribution of teachers by ethnicity and school type in different grades")
fig.tight_layout()
plt.show()

# %% [markdown]
# **Distribution of teachers by highest degree and class size in different grades**

# %%
fig = plt.figure(figsize=(8,8))

plt.subplot(2, 2, 1)
sns.heatmap(pd.crosstab(my_data.degreek,my_data.stark),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Kindergarten")
plt.xlabel("Class Size")
plt.ylabel("Highest degree of teacher")

plt.subplot(2, 2, 2)
sns.heatmap(pd.crosstab(my_data.degree1,my_data.star1),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("First Grade")
plt.xlabel("Class Size")
plt.ylabel("Highest degree of teacher")

plt.subplot(2, 2, 3)
sns.heatmap(pd.crosstab(my_data.degree2,my_data.star2),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Second Grade")
plt.xlabel("Class Size")
plt.ylabel("Highest degree of teacher")

plt.subplot(2, 2, 4)
sns.heatmap(pd.crosstab(my_data.degree3,my_data.star3),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Third Grade")
plt.xlabel("Class Size")
plt.ylabel("Highest degree of teacher")

plt.suptitle("Distribution of teachers by highest degree and class size in different grades")
fig.tight_layout()
plt.show()

# %% [markdown]
# **Distribution of teachers by highest degree and school type in different grades**

# %%
fig = plt.figure(figsize=(8,8))

plt.subplot(2, 2, 1)
sns.heatmap(pd.crosstab(my_data.degreek,my_data.schoolk),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Kindergarten")
plt.xlabel("School Type")
plt.ylabel("Highest degree of teacher")

plt.subplot(2, 2, 2)
sns.heatmap(pd.crosstab(my_data.degree1,my_data.school1),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("First Grade")
plt.xlabel("School Type")
plt.ylabel("Highest degree of teacher")

plt.subplot(2, 2, 3)
sns.heatmap(pd.crosstab(my_data.degree2,my_data.school2),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Second Grade")
plt.xlabel("School Type")
plt.ylabel("Highest degree of teacher")

plt.subplot(2, 2, 4)
sns.heatmap(pd.crosstab(my_data.degree3,my_data.school3),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Third Grade")
plt.xlabel("School Type")
plt.ylabel("Highest degree of teacher")

plt.suptitle("Distribution of teachers by highest degree and school type in different grades")
fig.tight_layout()
plt.show()

# %% [markdown]
# **Distribution of teachers by career ladder level and school type in different grades**

# %%
fig = plt.figure(figsize=(8,8))

plt.subplot(2, 2, 1)
sns.heatmap(pd.crosstab(my_data.ladderk,my_data.schoolk),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Kindergarten")
plt.xlabel("School Type")
plt.ylabel("Teacher career ladder level")

plt.subplot(2, 2, 2)
sns.heatmap(pd.crosstab(my_data.ladder1,my_data.school1),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("First Grade")
plt.xlabel("School Type")
plt.ylabel("Teacher career ladder level")

plt.subplot(2, 2, 3)
sns.heatmap(pd.crosstab(my_data.ladder2,my_data.school2),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Second Grade")
plt.xlabel("School Type")
plt.ylabel("Teacher career ladder level")

plt.subplot(2, 2, 4)
sns.heatmap(pd.crosstab(my_data.ladder3,my_data.school3),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Third Grade")
plt.xlabel("School Type")
plt.ylabel("Teacher career ladder level")

plt.suptitle("Distribution of teachers by career ladder level and school type in different grades")
fig.tight_layout()
plt.show()

# %% [markdown]
# **Distribution of teachers by career ladder level and class size in different grades**

# %%
fig = plt.figure(figsize=(8,8))

plt.subplot(2, 2, 1)
sns.heatmap(pd.crosstab(my_data.ladderk,my_data.stark),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Kindergarten")
plt.xlabel("Class Size")
plt.ylabel("Teacher career ladder level")

plt.subplot(2, 2, 2)
sns.heatmap(pd.crosstab(my_data.ladder1,my_data.star1),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("First Grade")
plt.xlabel("Class Size")
plt.ylabel("Teacher career ladder level")

plt.subplot(2, 2, 3)
sns.heatmap(pd.crosstab(my_data.ladder2,my_data.star2),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Second Grade")
plt.xlabel("Class Size")
plt.ylabel("Teacher career ladder level")

plt.subplot(2, 2, 4)
sns.heatmap(pd.crosstab(my_data.ladder3,my_data.star3),
            cmap="YlGnBu", annot=True, cbar=False,fmt='g')
plt.title("Third Grade")
plt.xlabel("Class Size")
plt.ylabel("Teacher career ladder level")

plt.suptitle("Distribution of teachers by career ladder level and class size in different grades")
fig.tight_layout()
plt.show()

# %% [markdown]
# # Analyzing Numerical Variables

# %%
fig = plt.figure(figsize=(8,8))

plt.subplot(2, 2, 1)
sns.histplot(data=my_data,x=my_data.readk,binwidth=50)
plt.title("Kindergarten")
plt.xlabel("Marks")

plt.subplot(2, 2, 2)
sns.histplot(data=my_data,x=my_data.read1,binwidth=50)
plt.title("First Grade")
plt.xlabel("Marks")

plt.subplot(2, 2, 3)
sns.histplot(data=my_data,x=my_data.read2,binwidth=50)
plt.title("Second Grade")
plt.xlabel("Marks")

plt.subplot(2, 2, 4)
sns.histplot(data=my_data,x=my_data.read3,binwidth=50)
plt.title("Third Grade")
plt.xlabel("Marks")

plt.suptitle("Distribution of total reading scaled score in different grades")
fig.tight_layout()

# %%
fig = plt.figure(figsize=(8,8))

plt.subplot(2, 2, 1)
sns.histplot(data=my_data,x=my_data.mathk,binwidth=50)
plt.title("Kindergarten")
plt.xlabel("Marks")

plt.subplot(2, 2, 2)
sns.histplot(data=my_data,x=my_data.math1,binwidth=50)
plt.title("First Grade")
plt.xlabel("Marks")

plt.subplot(2, 2, 3)
sns.histplot(data=my_data,x=my_data.math2,binwidth=50)
plt.title("Second Grade")
plt.xlabel("Marks")

plt.subplot(2, 2, 4)
sns.histplot(data=my_data,x=my_data.math3,binwidth=50)
plt.title("Third Grade")
plt.xlabel("Marks")

plt.suptitle("Distribution of total math scaled score in different grades")
fig.tight_layout()

# %%
fig = plt.figure(figsize=(8,8))

plt.subplot(2, 2, 1)
sns.histplot(data=my_data,x=my_data.experiencek,binwidth=5)
plt.title("Kindergarten")
plt.xlabel("Total teaching experience(years)")

plt.subplot(2, 2, 2)
sns.histplot(data=my_data,x=my_data.experience1,binwidth=5)
plt.title("First Grade")
plt.xlabel("Total teaching experience(years)")

plt.subplot(2, 2, 3)
sns.histplot(data=my_data,x=my_data.experience2,binwidth=5)
plt.title("Second Grade")
plt.xlabel("Total teaching experience(years)")

plt.subplot(2, 2, 4)
sns.histplot(data=my_data,x=my_data.experience3,binwidth=5)
plt.title("Third Grade")
plt.xlabel("Total teaching experience(years)")

plt.suptitle("Distribution of teacher's total teaching experience in different grades")
fig.tight_layout()
